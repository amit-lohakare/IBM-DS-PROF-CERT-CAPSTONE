# %% [markdown]
# # Description of Problem:
# **1. My mother lives in Panvel, a small town in Maharashtra state of India. My mother wants to start business of home made pickles and fries. For this I am searching the number of existing restaurants in and around Panvel**
#
# **2. I am using Foursquare API to collect the data.**

# %% [markdown]
# ## **Import necessary Libraries**

# %%
# !conda install -c conda-forge geopy --yes
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     openssl-1.1.1f             |       h516909a_0         2.1 MB  conda-forge
#     certifi-2019.11.28         |   py36h9f0ad1d_1         149 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         673 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.0.1-py_0 conda-forge
#     branca:  0.4.0-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# ...

# %% [markdown]
# ### _Define Foursquare Credentials and Version_

# %%
CLIENT_ID = 'ZJZZJF4AATOYQ1TKQVPOWTT3KVVJ0VY1WSI54QRXKN444QLS' # your Foursquare ID
CLIENT_SECRET = 'QW3NSCYP3VW4NH12ZUS2GLOZ02N4RSMHCOH2Y5QS5K4X3SZ5' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ZJZZJF4AATOYQ1TKQVPOWTT3KVVJ0VY1WSI54QRXKN444QLS
# CLIENT_SECRET:QW3NSCYP3VW4NH12ZUS2GLOZ02N4RSMHCOH2Y5QS5K4X3SZ5

# %% [markdown]
# **Since my mother is staying at Panvel, let's start by converting Panvel to its latitude and longitude coordinates**

# %%
# convert an address into latitude and longitude values
from geopy.geocoders import Nominatim

address = 'Panvel, Maharashtra'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 18.96558885 73.10288130582491

# %% [markdown]
# **Let's define a query to search for Hotels that is within 15 kilo metres from the Panvel**

# %%
search_query = 'Hotels'
radius = 15000
print(search_query + ' .... OK!')
# Out:
# Hotels .... OK!

# %% [markdown]
# **Define the corresponding URL**

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=ZJZZJF4AATOYQ1TKQVPOWTT3KVVJ0VY1WSI54QRXKN444QLS&client_secret=QW3NSCYP3VW4NH12ZUS2GLOZ02N4RSMHCOH2Y5QS5K4X3SZ5&ll=18.96558885,73.10288130582491&v=20180604&query=Hotels&radius=15000&limit=30'

# %% [markdown]
# **Send the GET Request and examine the results**

# %%
# library to handle requests
import requests

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e847cc00cc1fd001b22e5b9'},
#  'response': {'venues': [{'id': '5093d9cce4b0d8a7b2828ba6',
#     'name': 'hotel sirka',
#     'location': {'lat': 18.987443491150003,
#      'lng': 73.10782025771093,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.987443491150003,
#        'lng': 73.10782025771093}],
#      'distance': 2487,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1585741087',
#     'hasPerk': False},
#    {'id': '5315936a11d2069de3615743',
#     'name': 'Hotel Shri Datta (namana)',
#     'location': {'lat': 18.987640624796896,
#      'lng': 73.1160384590643,
# ...

# %% [markdown]
# **Get relevant part of JSON and transform it into a pandas dataframe**

# %%
# tranform JSON file into a pandas dataframe
from pandas.io.json import json_normalize

# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 2  [{'id': '4bf58dd8d48988d147941735', 'name': 'D...    False
# 3  [{'id': '4bf58dd8d48988d147941735', 'name': 'D...    False
# 4  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
#
#                          id             location.address location.cc  \
# 0  5093d9cce4b0d8a7b2828ba6                          NaN          IN
# 1  5315936a11d2069de3615743                          NaN          IN
# 2  50097e76e4b06223afab8bf9                          NaN          IN
# 3  5244646b11d2da307e95486c  NH17, Near Shirdhon Village          IN
# 4  53d73b94498e73e426d7004d                 Opp St Stand          IN
#
#   location.city location.country location.crossStreet  location.distance  \
# 0           NaN            India                  NaN               2487
# ...

# %%
dataframe.shape
# Out:
# (30, 17)

# %% [markdown]
# **Define information of interest and filter dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                             name                                categories  \
# 0                    hotel sirka                         Indian Restaurant
# 1      Hotel Shri Datta (namana)                         Indian Restaurant
# 2                  hotel suruchi                                     Diner
# 3                  Hotel Sangram                                     Diner
# 4                  Hotel Sarowar                         Indian Restaurant
# 5                     V M hotels             Vegetarian / Vegan Restaurant
# 6                  Hotel Sarovar                         Indian Restaurant
# 7                    Hotel Surya                                Restaurant
# 8              hotel Shree Datta                         Indian Restaurant
# 9                 Hotel sai deep           Southern / Soul Food Restaurant
# 10           Hotel Scottish Blue                         Indian Restaurant
# ...

# %% [markdown]
# **Let's visualize the Italian restaurants that are nearby**

# %%
# map rendering library
import folium

venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Lets find hotels having highest foot print. Those hotels can be prospective customer and can get good business**

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
trending_venues_df
# Out:
#                             name                                categories  \
# 0                    hotel sirka                         Indian Restaurant
# 1      Hotel Shri Datta (namana)                         Indian Restaurant
# 2                  hotel suruchi                                     Diner
# 3                  Hotel Sangram                                     Diner
# 4                  Hotel Sarowar                         Indian Restaurant
# 5                     V M hotels             Vegetarian / Vegan Restaurant
# 6                  Hotel Sarovar                         Indian Restaurant
# 7                    Hotel Surya                                Restaurant
# 8              hotel Shree Datta                         Indian Restaurant
# 9                 Hotel sai deep           Southern / Soul Food Restaurant
# 10           Hotel Scottish Blue                         Indian Restaurant
# ...

# %% [markdown]
# ## Results:
# As per the anaysis of near by places, there are 30 restaurants available around the radius of 15 km which can be prospective customers for my mother's pickle and fries business.
